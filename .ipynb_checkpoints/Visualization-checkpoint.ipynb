# %%
# visualization
# python matplotlib and seaborn, tensorflow in tensorboard

# %%
# from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5,6,7,8,9],[3,4,5,5,3,5,6,7,8])
plt.show()

# %%
plt.scatter([1,2,3,4,5,6,7,8,9],[3,4,5,5,3,5,6,7,8])
plt.show()

# %%
plt.plot([1,2,3,4,5,6,7,8,9],[3,4,5,5,3,5,6,7])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.plot([1,2,3,4,5,6,7,8,9],[3,4,5,5,3,5,6,7])
#       2 plt.show()
#
# File c:\Users\Ducat\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Ducat\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
# ...

# %%
plt.plot([1,2,3,4,5,6,7,8,9],[3,4,5,5,3,5,6,7,8])
plt.xticks([1,4,6,8,10])
plt.show()
